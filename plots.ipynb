# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /home/fei/.local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
y1 = []
with open('temp.txt') as f:
    for line in f:
        y1.append(int(line.strip()))

# %%
plt.plot(y2[:450])
plt.plot(y1[:450])
plt.plot(y3)
plt.xlabel('# minibatch')
plt.ylabel('accuracy')
plt.legend(['intensity = 0.3', 'intensity = 0.5', 'intensity = 0.7'], loc=3)
plt.savefig('error.pdf')

# %%
y2 = []
with open('temp2.txt') as f:
    for line in f:
        y2.append(int(line.strip()))

# %%
y2
# Out:
# [100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
# ...

# %%
y3 = []
with open('temp4.txt') as f:
    for line in f:
        y3.append(int(line.strip()))

# %%
y4 = []
with open('temp3.txt') as f:
    for line in f:
        y4.append(int(line.strip()))

# %%
plt.plot(y4[:450])
plt.plot(y3)
plt.ylim([0,110])
plt.xlabel('# minibatch')
plt.ylabel('accuracy')
plt.legend(['with adversarial training', 'with no adversarial training'
], loc = 5)
plt.savefig('error_cmp.pdf')
